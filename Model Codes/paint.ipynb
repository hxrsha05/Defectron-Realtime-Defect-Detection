# %% [markdown]
# Paint Defect Detection Code

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov9c.pt') 

model.train(
    data="wall_defects/data.yaml",
    epochs=200,
    imgsz=640,              
    batch=32,
    device=0,
    project="wall_defect_realtime",
    name="yolov9c_wall_run1",
    pretrained=True,
    amp=True,               
    verbose=True
)
