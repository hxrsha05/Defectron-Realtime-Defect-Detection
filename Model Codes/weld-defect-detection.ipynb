# %% [markdown]
# Weld Defect Detection Model

# %% [markdown]
# from ultralytics import YOLO

# %%
model = YOLO("yolov10m.pt")

model.train(
    data="data.yaml",
    epochs=150,
    imgsz=640,
    batch=16,
    device=0,
    save_period=4,  
    project="weld_v10_project",
    name="yolov10_roboflow_defects",
    pretrained=True,
    verbose=True
)
