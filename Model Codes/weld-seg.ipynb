# %% [markdown]
# Weld Segmentation Code

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m-seg.pt")  

model.train(
    data="path/to/data.yaml",    
    epochs=150,                  
    imgsz=640,                    
    batch=16,                    
    device=0,                     
    project="segmentation_weld_project",  
    name="yolov8_seg_run1",      
    pretrained=True,              
    verbose=True                  
)
